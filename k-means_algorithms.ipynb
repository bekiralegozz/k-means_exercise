# %%
import numpy as np
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=1000, centers=7, n_features=10,random_state=0)

print(X,y)
# Out:
# [[-5.47279421  3.94971569  0.27978765 ...  2.90664596  8.32450571
#    2.44267353]
#  [ 0.94544766 -2.99041196  8.48260108 ... -5.33430554 -1.36404614
#   -5.39667238]
#  [ 0.70826671  5.10624372  3.00251949 ...  6.73605923  9.57149338
#   -1.00478373]
#  ...
#  [ 5.98531897  0.32242761  3.04668352 ...  6.53422613  5.42044731
#    6.17260654]
#  [ 0.4653439   5.07851565  0.24712359 ...  8.00010383 10.15844275
#   -0.85740481]
#  [-1.68907051 -0.24693382  3.64888363 ... -6.67564338 -5.80180001
#   -1.65296105]] [3 5 0 5 5 6 0 0 2 3 3 1 6 2 5 6 4 1 2 6 0 0 6 4 3 3 0 4 3 5 0 5 6 3 3 3 5
#  2 4 6 4 4 3 4 1 4 4 5 4 6 1 4 4 3 5 3 3 2 2 0 2 0 4 5 5 2 4 1 4 0 5 4 4 1
#  5 4 5 5 1 0 0 0 3 0 1 3 4 6 2 6 0 6 1 4 0 5 3 4 1 3 3 2 0 6 1 4 1 4 1 2 3
#  6 3 6 2 5 5 2 0 4 4 1 1 4 0 1 4 3 1 6 5 4 0 0 3 3 2 1 6 3 0 5 5 2 2 1 4 6
#  3 5 4 3 2 3 5 5 3 6 0 4 4 3 6 6 2 2 3 1 0 2 3 2 5 5 0 3 4 1 2 3 6 2 5 2 2
#  6 5 6 6 0 5 3 6 5 4 3 3 3 1 6 3 6 3 2 0 2 6 6 0 0 0 5 6 3 1 2 2 6 2 4 0 5
# ...

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=7)

# %%
fitted_km = km.fit(X)
# Out:
# /Users/bekir.alegoz/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
km.cluster_centers_
# Out:
# array([[ 5.83198563,  0.57854036,  1.35599567,  8.51115285, -8.57564081,
#         -8.24643729, -9.60791931,  6.66010884,  5.56029675,  7.38644934],
#        [-6.81756842, -7.78549896,  3.11854051, -7.24187699, -6.06962609,
#         -2.62435024,  6.43510376, -8.05640057,  6.75611038, -8.08957904],
#        [ 0.9758394 ,  4.30617913,  2.05466896,  0.90885364, -1.51767672,
#          2.93937885, -1.25520312,  7.8392368 ,  9.28165173, -2.33456374],
#        [ 1.40668789, -1.24227769,  9.78042745, -7.96544799, -5.82441651,
#         -6.78098071,  3.05494066, -4.9390478 , -0.67570219, -5.10486755],
#        [ 9.56742048,  5.99647863, -0.77290275,  5.60124046, -7.6247358 ,
#          2.82757757, -7.13142334,  8.90058885,  0.43432262, -1.70312311],
#        [-2.81738375, -1.24570883,  3.95559987, -8.79474418,  3.33632446,
#          3.41300643, -5.78581075, -7.41427127, -3.71404559, -2.71610068],
#        [-4.71661692,  5.47135324, -0.87849149,  1.37222253, -9.60553433,
# ...

# %%
km.labels_
# Out:
# array([5, 0, 0, ..., 2, 5, 1], dtype=int32)

# %%
cluster_centers[0]
# Out:
# array([29.18658423, 19.26773454, 24.72766165, 33.1504379 ,  1.88301429])

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0], X[:,1] ,c=km.labels_)

# %%
,

# %%
X.random
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 X.random
#
# AttributeError: 'numpy.ndarray' object has no attribute 'random'

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X.shape, X.ndim
# Out:
# ((1000, 10), 2)

# %%
y.shape, y.ndim
# Out:
# ((1000,), 1)

# %%
y.reshape(-1,1).T
# Out:
# array([[3, 5, 0, 5, 5, 6, 0, 0, 2, 3, 3, 1, 6, 2, 5, 6, 4, 1, 2, 6, 0, 0,
#         6, 4, 3, 3, 0, 4, 3, 5, 0, 5, 6, 3, 3, 3, 5, 2, 4, 6, 4, 4, 3, 4,
#         1, 4, 4, 5, 4, 6, 1, 4, 4, 3, 5, 3, 3, 2, 2, 0, 2, 0, 4, 5, 5, 2,
#         4, 1, 4, 0, 5, 4, 4, 1, 5, 4, 5, 5, 1, 0, 0, 0, 3, 0, 1, 3, 4, 6,
#         2, 6, 0, 6, 1, 4, 0, 5, 3, 4, 1, 3, 3, 2, 0, 6, 1, 4, 1, 4, 1, 2,
#         3, 6, 3, 6, 2, 5, 5, 2, 0, 4, 4, 1, 1, 4, 0, 1, 4, 3, 1, 6, 5, 4,
#         0, 0, 3, 3, 2, 1, 6, 3, 0, 5, 5, 2, 2, 1, 4, 6, 3, 5, 4, 3, 2, 3,
#         5, 5, 3, 6, 0, 4, 4, 3, 6, 6, 2, 2, 3, 1, 0, 2, 3, 2, 5, 5, 0, 3,
#         4, 1, 2, 3, 6, 2, 5, 2, 2, 6, 5, 6, 6, 0, 5, 3, 6, 5, 4, 3, 3, 3,
#         1, 6, 3, 6, 3, 2, 0, 2, 6, 6, 0, 0, 0, 5, 6, 3, 1, 2, 2, 6, 2, 4,
#         0, 5, 3, 5, 4, 1, 6, 0, 3, 3, 6, 3, 3, 6, 1, 0, 1, 6, 5, 1, 1, 5,
#         1, 4, 4, 5, 1, 0, 1, 2, 4, 6, 1, 6, 4, 5, 2, 6, 5, 2, 2, 0, 4, 5,
#         1, 4, 1, 0, 3, 0, 4, 5, 2, 1, 2, 4, 5, 5, 1, 4, 5, 5, 1, 6, 1, 1,
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0], X[:,1] ,c=y)

# %%
def kmeans(k,iter_max,X):
    center_arrays= X[np.random.choice(X.shape[0], 5, replace=False)]
    
    for iteration in range(iter_max):
        distances = np.linalg.norm(X[:, np.newaxis] - center_arrays, axis=2)
        cluster_assignment = np.argmin(distances, axis=1)
    
    
        new_centerarr = np.array([X[cluster_assignment == i].mean(axis=0) for i in range(k)])
    
   
        if np.all(center_arrays == new_centerarr):
            break
    
        center_arays = new_centerarr

# %%
X[np.random.choice(X.shape[0], 5, replace=False)]
# Out:
# array([[  9.81336358,   5.01085337,  -1.05086054,   4.43029792,
#          -6.62234319,   4.18260715,  -5.88093227,   7.74868571,
#           0.34569942,  -2.10833188],
#        [ -3.65136937,  -1.75178902,   3.84716479,  -8.13678403,
#           3.96309371,   3.61546317,  -6.82096524,  -7.22161455,
#          -3.03425415,  -2.03530636],
#        [  5.17455806,   0.79091556,   1.96026059,   8.25561587,
#          -8.11848451,  -8.65840016, -10.56680272,   8.07871377,
#           8.05157663,   9.0962125 ],
#        [ -6.27456084,  -6.83212258,   2.17773617,  -7.73446361,
#          -6.47105152,  -2.03345069,   6.42892112,  -8.94429631,
#           6.80799796,  -8.25617891],
#        [  1.28727311,  -1.72889693,  11.07240407,  -9.1291644 ,
#          -5.3951279 ,  -7.26068625,   2.12219837,  -4.74049662,
#          -0.80425107,  -3.47507737]])

# %%
np.random.choice(X.shape[0], 5, replace=False)
# Out:
# array([332, 418, 155, 364, 268])

# %%
X[0]
# Out:
# array([ -5.47279421,   3.94971569,   0.27978765,   0.85649757,
#        -10.07321275,   0.95883759,   2.77230319,   2.90664596,
#          8.32450571,   2.44267353])

# %%
def distance(X,center_arrays):
    alldistances=[]
    for i in range(X.shape[0]):
        cldistance=[]
        for k in range(center_arrays.shape[0]):
            distance =0
            for j in range(X.shape[1]):
                distance += ((X[i][j])-(center_arrays[k][j]))**2
    
            distance= distance**0.5
            cldistance.append(distance)
        alldistances.append(cldistance)
    return alldistances



def distance(X, center_arrays):
    squared_differences = (X[:, np.newaxis] - center_arrays) ** 2

    squared_distances = np.sum(squared_differences, axis=-1)

    distances = np.sqrt(squared_distances)

    return distances

# %%
X, y = make_blobs(n_samples=100000, centers=7, n_features=10,random_state=0)

def kmeans(k,iter_max,X):
    center_arrays= X[np.random.choice(X.shape[0], k, replace=False)]
    
    for iteration in range(iter_max):
        distances = np.linalg.norm(X[:, np.newaxis] - center_arrays, axis=2)
        #distances= distance(X,center_arrays)
        
        
        cluster_assignment = np.argmin(distances, axis=1)
    
    
        new_centerarr = np.array([X[cluster_assignment == i].mean(axis=0) for i in range(k)])
    
   
        if np.all(center_arrays == new_centerarr):
            break
    
        center_arrays = new_centerarr
        
    return center_arrays,cluster_assignment
        
a=kmeans(7,100000,X)
print(a)
plt.scatter(X[:,0], X[:,1] ,c=a[1])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
xz= X[:,0]
yz= X[:,1]
zz=X[:,2]
ax.scatter(xz, yz, zz, c=a[1])

# %%
X[:,0]
# Out:
# array([-5.47279421e+00,  9.45447663e-01,  7.08266708e-01,  1.28727311e+00,
#         1.14366709e+00, -7.25806514e+00,  1.60150153e+00,  1.06380155e+00,
#         8.99643124e+00, -4.30938107e+00, -4.57266498e+00,  4.86641864e+00,
#        -6.61066054e+00,  9.50923694e+00,  6.27306542e-01, -7.56264791e+00,
#        -2.96472080e+00,  5.63671331e+00,  1.05195911e+01, -6.99841872e+00,
#         6.84432716e-01,  9.60587967e-01, -7.03443215e+00, -2.75047545e+00,
#        -3.96012621e+00, -5.60612479e+00,  8.44361439e-01, -1.64829125e+00,
#        -4.41428835e+00,  1.63166640e+00,  1.80892082e+00,  2.61016573e+00,
#        -5.80302683e+00, -4.84498546e+00, -4.58474332e+00, -5.69772986e+00,
#         1.09860365e+00,  1.07661773e+01, -5.12762507e+00, -9.65880627e+00,
#        -3.34322634e+00, -2.88119374e+00, -4.13713577e+00, -2.78216186e+00,
#         4.46464126e+00, -3.56806539e-01, -2.61593473e+00,  1.42153162e+00,
# ...
